# %%
import pandas as pd

# %%
# import pyarrow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pyarrow
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-13.0.0.tar.gz (1.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pyarrow
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [287 lines of output]
#   <string>:34: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   WARNING setuptools_scm.pyproject_reading toml section missing 'pyproject.toml does not contain a tool.setuptools_scm section'
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-312
# ...

# %%
# pip install fastparquet
# Out:
# ...
#   Using cached fastparquet-2023.10.1.tar.gz (393 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached cramjam-2.7.0-cp312-none-win_amd64.whl.metadata (4.1 kB)
# ...
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# ...
# Using cached cramjam-2.7.0-cp312-none-win_amd64.whl (1.4 MB)
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# ...
# Failed to build fastparquet
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [134 lines of output]
# ...

# %%
from pyarrow import parquet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pyarrow import parquet
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
df=pd.read_parquet("date=2023-10-27",engine='pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
# ...

# %%
df.head()

# %%
df.to_save("date=2023-10-30.csv",index=False)
